# %%
import pandas as pd
import os
from datetime import datetime, timedelta

# %pip install python-dateutil

from dateutil import parser
import numpy as np
# Out:
# Requirement already satisfied: python-dateutil in c:\users\nwalr\anaconda3\envs\insulinmodel\lib\site-packages (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\nwalr\anaconda3\envs\insulinmodel\lib\site-packages (from python-dateutil) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_dir = os.getcwd()
data_dir = os.path.join(os.getcwd(), "Final_Dataset", "Filtered_Data")
print(data_dir)

train_data = pd.DataFrame()
test_data = pd.DataFrame()

print(train_data)
print(test_data)
# Out:
# c:\Users\nwalr\OneDrive - Georgia Institute of Technology\VIP\TreatmentSystems\Final_Dataset\Filtered_Data
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
for file_name in os.listdir(data_dir):
    print(file_name)
    file_path = os.path.join(data_dir, file_name)
    dataframe = pd.read_csv(file_path)

    #Find first 10 days in data
    times = pd.to_datetime(dataframe['time'])
    min_date = times.min()
    max_date = times.max()
    days_difference = (max_date - min_date).days

    print(days_difference)
    #Find last 4 days in data
# Out:
# HUPA0001P.csv
# 14
# HUPA0002P.csv
# 11
# HUPA0003P.csv
# 13
# HUPA0004P.csv
# 11
# HUPA0005P.csv
# 13
# HUPA0006P.csv
# 7
# HUPA0007P.csv
# 13
# HUPA0009P.csv
# 13
# HUPA0010P.csv
# 10
# HUPA0011P.csv
# 13
# HUPA0014P.csv
# 13
# HUPA0015P.csv
# 13
# HUPA0016P.csv
# 13
# HUPA0017P.csv
# 12
# HUPA0018P.csv
# 13
# HUPA0019P.csv
# 12
# HUPA0020P.csv
# 9
# HUPA0021P.csv
# 8
# HUPA0022P.csv
# 13
# HUPA0023P.csv
# 13
# HUPA0024P.csv
# 10
# HUPA0025P.csv
# 13
# HUPA0026P.csv
# 14
# HUPA0027P.csv
# 14
# HUPA0028P.csv
# 14
